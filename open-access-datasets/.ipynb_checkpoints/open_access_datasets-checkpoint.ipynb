# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#General-Information" data-toc-modified-id="General-Information-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>General Information</a></span><ul class="toc-item"><li><span><a href="#What-are-open-access-datasets?" data-toc-modified-id="What-are-open-access-datasets?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>What are open access datasets?</a></span></li><li><span><a href="#Why-would-I-want-to-use-an-open-access-dataset?" data-toc-modified-id="Why-would-I-want-to-use-an-open-access-dataset?-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Why would I want to use an open access dataset?</a></span></li><li><span><a href="#Where-can-I-find-them?" data-toc-modified-id="Where-can-I-find-them?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Where can I find them?</a></span></li><li><span><a href="#Gaining-access" data-toc-modified-id="Gaining-access-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Gaining access</a></span></li><li><span><a href="#Logistical-issues" data-toc-modified-id="Logistical-issues-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Logistical issues</a></span><ul class="toc-item"><li><span><a href="#Hosting-the-data" data-toc-modified-id="Hosting-the-data-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Hosting the data</a></span></li><li><span><a href="#Learning-the-data" data-toc-modified-id="Learning-the-data-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Learning the data</a></span></li></ul></li></ul></li><li><span><a href="#HCP-Young-Adult-Behavioral-Data" data-toc-modified-id="HCP-Young-Adult-Behavioral-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>HCP Young Adult Behavioral Data</a></span><ul class="toc-item"><li><span><a href="#Data-Dictionary" data-toc-modified-id="Data-Dictionary-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data Dictionary</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Filtering-a-dataframe" data-toc-modified-id="Filtering-a-dataframe-2.1.0.1"><span class="toc-item-num">2.1.0.1&nbsp;&nbsp;</span>Filtering a dataframe</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#HCP-Freesurfer-Structural-Data" data-toc-modified-id="HCP-Freesurfer-Structural-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>HCP Freesurfer Structural Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Filter-dataframe" data-toc-modified-id="Filter-dataframe-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Filter dataframe</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # General Information
#
# ## What are open access datasets?
# Open access datasets are datasets that are free and accessible to "anyone". These datasets have been collected by a group of researchers who have decided to share this data with the scientific community in order to promote openness, reproducibility, and more research. Typically, one must register to a dataset's website and create an account where they agree to the dataset's term of use. There may be an approval process that you need to go through before you receive access. There are two types of open access datasets: large multi-site projects and datasets that are from a single group/study that have been fully or partially released to the community.
#
# ## Why would I want to use an open access dataset?
# * Pros
#     * Large sample sizes - Open access datasets typically have very large sample sizes, as they are often multi-site studies.
#     * Free data collection
#     * Data can be very high quality, which many researchers might not be able to acquire themselves
#     * Data can come preprocessed
#     * Data (especially behavioral data) is usually clean
# * Cons
#     * Over analyzed datasets?
#     * Might not be able to test your specific hypotheses
#     * Some multi-side studies can be very troublesome
#     * Data can come preprocessed
#
#
# ## Where can I find them?
# * [OpenNeuro](https://openneuro.org/)
#     * Database of publically available single-study datasets
# * [Brain Genomics Superstruct Project (GSP)](https://dataverse.harvard.edu/dataverse/GSP)<img src=images/gsp.jpg />
#     * A collection of neuroimaing, behavior, cognitive, and personality data for over 1,500 human participants
#     * This dataset was used in [Yeo et al., 2011](https://journals.physiology.org/doi/full/10.1152/jn.00338.2011) to create the widely used Yeo 7-network atlas
# * [Adolescent Brain Cognitive Development (ABCD)](https://nda.nih.gov/abcd)
#     * Longitudinal study of brain development and child health from 21 sites
#     * Measured social, emotional, cognitive development, as well as health and environmental outcomes
#     * This dataset is somewhat notorious for its various issues
#         * The imaging data is very troublesome, as it is from different sites, with different scanners, scanner software, head-coils, etc.
# * [Human Connectome Project (HCP)](https://www.humanconnectome.org/study/hcp-young-adult)<img src=images/hcp_mmp.png />
#     * The HCP young adult dataset was collected on the same MRI scanner model across three different sites
#     * It is very high quality considering the multi-site nature of the dataset and the large sample size (1200)
#         * The researchers took careful consideration of the issues with multi-site studies and ensured that all studies were using the same type of scanner, scanner software, head-coil, and protocol
#     * Includes multi-modal data from fMRI tasks, fMRI resting state, DWI, and high resolution T1 structural scans, along with behavioral and cognitive data
#     * Most of the data is available fully preprocessed via their [Minimal Preprocessing Pipeline](https://pubmed.ncbi.nlm.nih.gov/23668970/)
#     * Additional HCP datasets
#         * [HCP Development](https://www.humanconnectome.org/study/hcp-lifespan-development)
#         * [HCP Aging](https://www.humanconnectome.org/study/hcp-lifespan-aging)
#         * Human disease (Alzheimer's, anxiety and depression, etc.) datasets to come
#
# * [Autism Brain Imaging Data Exchange (ABIDE)](http://fcon_1000.projects.nitrc.org/indi/abide/abide_I.html)
# * [Open Access Series of Imaging Studies (OASIS)](https://www.oasis-brains.org/)
# * [Alzheimer's Disease Neuroimaing Initiative (ADNI)](http://adni.loni.usc.edu/)
#
#
#
# ## Gaining access
# It turns out that "open access" is not as accessible as you would think. Typically, researchers will have to apply to gain access to a dataset. This can be just signing up and creating an account for the dataset, or submitting an pseudo application in which you will have to say who you are and what you intend to use the data for. <br>
#
# For this workshop, we will focus on the young adult (original) HCP dataset. The following steps will help you gain access to this dataset:
#
# 1. Create an account on [ConnectomeDB](https://db.humanconnectome.org/app/template/Login.vm;jsessionid=5629BEC4DD00C13DB36AAD1C07677226).
# <br>
#
# 2. Login with your connectomeDB account
# <br>
#
# 3. Install the Aspera Connect plugin <img src=images/aspera_connect.png height=100 width=700 />
# <br>
#
# 4. Log back into [ConnectomeDB](https://db.humanconnectome.org/app/template/Login.vm;jsessionid=5629BEC4DD00C13DB36AAD1C07677226) and accept the usage terms.
# <br>
#
# 5. Download the behavioral and Freesurfer structural data <img height=400 width=500 src=images/hcp_download.png />
# <br>
#
#
#
#
# ## Logistical issues
#
# ### Hosting the data
# Some datasets, like neuroimaging data, can be very, VERY large. For example, a single subject's MRI data from the young adult HCP is over 40GB. Multiple that by 1200 (or slighly less) subjects, and you get 48TB of data, which is impossible for a single computer to host. In addition, it would be inefficient to have multiple researchers in a lab all have the same (large) dataset on their personal computers. Instead, there are two options: 1) Find a server to host the data for you in a common space that is accessible to everyone, or 2) only download a subset of the data. For the young adult HCP data, our lab has gone with option 1 and has teamed up with the computer science high performance cluster people at Temple to host the data on Owlsnest.
#
# ### Learning the data
# Open access datasets may have variables that you are unfamiliar with, or that are named/abbreviated a specific way. To find out what variables are and what they aim to measure, refer to the dataset's data dictionary. Datasets may also come with documentation that describe what the dataset is, how it was acquired, how the data is structed and named. For imaging datasets, this is particularly important as the documentation will help you navigate directory structures to find the data you are interested in.
#
#
# ***
# # HCP Young Adult Behavioral Data
# For this workshop, we will explore the behavioral and Freesurfer structural data from the young adult HCP data. Once these have been downloaded, place them somewhere where you can access them via the command line.

# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.2"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ## Data Dictionary
# When we open the  behavioral data spreadsheet, we can see that variables are named as acronyms that might be unfamiliar. A data dictionary is a file (usually a csv of excel file) that acts as a sort of key to tell you what variables are, how they are named, and what they measure.

# %%
behav_data <- read.csv('/Users/Administrator/Downloads/unrestricted_hspopal_6_17_2020_13_26_49.csv')
colnames(behav_data)
# Out:
#   [1] "Subject"
#   [2] "Release"
#   [3] "Acquisition"
#   [4] "Gender"
#   [5] "Age"
#   [6] "X3T_Full_MR_Compl"
#   [7] "T1_Count"
#   [8] "T2_Count"
#   [9] "X3T_RS.fMRI_Count"
#  [10] "X3T_RS.fMRI_PctCompl"
#  [11] "X3T_Full_Task_fMRI"
#  [12] "X3T_tMRI_PctCompl"
#  [13] "fMRI_WM_PctCompl"
#  [14] "fMRI_Gamb_PctCompl"
#  [15] "fMRI_Mot_PctCompl"
#  [16] "fMRI_Lang_PctCompl"
#  [17] "fMRI_Soc_PctCompl"
#  [18] "fMRI_Rel_PctCompl"
#  [19] "fMRI_Emo_PctCompl"
#  [20] "X3T_dMRI_Compl"
#  [21] "X3T_dMRI_PctCompl"
#  [22] "dMRI_3T_ReconVrs"
#  [23] "fMRI_3T_ReconVrs"
#  [24] "X7T_Full_MR_Compl"
#  [25] "X7T_RS.fMRI_Count"
#  [26] "X7T_RS.fMRI_PctCompl"
#  [27] "X7T_Full_Task_fMRI"
#  [28] "X7T_tMRI_PctCompl"
#  [29] "fMRI_Movie_Compl"
#  [30] "fMRI_Movie_PctCompl"
#  [31] "fMRI_Ret_Compl"
#  [32] "fMRI_Ret_PctCompl"
#  [33] "X7T_dMRI_Compl"
#  [34] "X7T_dMRI_PctCompl"
#  [35] "X7T_fMRI_Mov_Vrs"
#  [36] "MEG_AnyData"
#  [37] "MEG_FullProt_Compl"
#  [38] "MEG_HeadModel_Avail"
#  [39] "MEG_CortRibn_Avail"
#  [40] "MEG_Anatomy_Avail"
#  [41] "MEG_Anatomy_Compl"
#  [42] "MEG_Noise_Avail"
#  [43] "MEG_Noise_Compl"
#  [44] "MEG_RS_Avail"
#  [45] "MEG_RS_Compl"
#  [46] "MEG_WM_Avail"
#  [47] "MEG_WM_Compl"
#  [48] "MEG_StoryMath_Avail"
#  [49] "MEG_StoryMath_Compl"
#  [50] "MEG_Motor_Avail"
#  [51] "MEG_Motor_Compl"
#  [52] "Non.TB_Compl"
#  [53] "VisProc_Compl"
#  [54] "DelDisc_Compl"
#  [55] "SCPT_Compl"
#  [56] "IWRD_Compl"
#  [57] "PMAT_Compl"
#  [58] "VSPLOT_Compl"
#  [59] "EmoRecog_Compl"
#  [60] "NEO.FFI_Compl"
#  [61] "ASR.Syn_Compl"
#  [62] "ASR.DSM_Compl"
#  [63] "Toolbox_Compl"
#  [64] "MMSE_Compl"
#  [65] "PSQI_Compl"
#  [66] "Alert_Compl"
#  [67] "ASQ_Compl"
#  [68] "FamPsychNeuro_Compl"
#  [69] "SSAGA_Compl"
#  [70] "SSAGA_Demo_Compl"
#  [71] "SSAGA_Mental_Compl"
#  [72] "SSAGA_Alc_Compl"
#  [73] "SSAGA_Illicit_Compl"
#  [74] "SSAGA_Tob_Compl"
#  [75] "SSAGA_Mj_Compl"
#  [76] "QC_Issue"
#  [77] "MRsession_Scanner_3T"
#  [78] "MRsession_Scans_3T"
#  [79] "MRsession_Label_3T"
#  [80] "MRsession_Scanner_7T"
#  [81] "MRsession_Scans_7T"
#  [82] "MRsession_Label_7T"
#  [83] "MEGsession_Scanner"
#  [84] "MEGsession_Scans"
#  [85] "MEGsession_Label"
#  [86] "Alpha_Peak"
#  [87] "Beta_Peak"
#  [88] "MMSE_Score"
#  [89] "PSQI_Score"
#  [90] "PSQI_Comp1"
#  [91] "PSQI_Comp2"
#  [92] "PSQI_Comp3"
#  [93] "PSQI_Comp4"
#  [94] "PSQI_Comp5"
#  [95] "PSQI_Comp6"
#  [96] "PSQI_Comp7"
#  [97] "PSQI_BedTime"
#  [98] "PSQI_Min2Asleep"
#  [99] "PSQI_GetUpTime"
# [100] "PSQI_AmtSleep"
# [101] "PSQI_Latency30Min"
# [102] "PSQI_WakeUp"
# [103] "PSQI_Bathroom"
# [104] "PSQI_Breathe"
# [105] "PSQI_Snore"
# [106] "PSQI_TooCold"
# [107] "PSQI_TooHot"
# [108] "PSQI_BadDream"
# [109] "PSQI_Pain"
# [110] "PSQI_Other"
# [111] "PSQI_Quality"
# [112] "PSQI_SleepMeds"
# [113] "PSQI_DayStayAwake"
# [114] "PSQI_DayEnthusiasm"
# [115] "PSQI_BedPtnrRmate"
# [116] "PicSeq_Unadj"
# [117] "PicSeq_AgeAdj"
# [118] "CardSort_Unadj"
# [119] "CardSort_AgeAdj"
# [120] "Flanker_Unadj"
# [121] "Flanker_AgeAdj"
# [122] "PMAT24_A_CR"
# [123] "PMAT24_A_SI"
# [124] "PMAT24_A_RTCR"
# [125] "ReadEng_Unadj"
# [126] "ReadEng_AgeAdj"
# [127] "PicVocab_Unadj"
# [128] "PicVocab_AgeAdj"
# [129] "ProcSpeed_Unadj"
# [130] "ProcSpeed_AgeAdj"
# [131] "DDisc_SV_1mo_200"
# [132] "DDisc_SV_6mo_200"
# [133] "DDisc_SV_1yr_200"
# [134] "DDisc_SV_3yr_200"
# [135] "DDisc_SV_5yr_200"
# [136] "DDisc_SV_10yr_200"
# [137] "DDisc_SV_1mo_40K"
# [138] "DDisc_SV_6mo_40K"
# [139] "DDisc_SV_1yr_40K"
# [140] "DDisc_SV_3yr_40K"
# [141] "DDisc_SV_5yr_40K"
# [142] "DDisc_SV_10yr_40K"
# [143] "DDisc_AUC_200"
# [144] "DDisc_AUC_40K"
# [145] "VSPLOT_TC"
# [146] "VSPLOT_CRTE"
# [147] "VSPLOT_OFF"
# [148] "SCPT_TP"
# [149] "SCPT_TN"
# [150] "SCPT_FP"
# [151] "SCPT_FN"
# [152] "SCPT_TPRT"
# [153] "SCPT_SEN"
# [154] "SCPT_SPEC"
# [155] "SCPT_LRNR"
# [156] "IWRD_TOT"
# [157] "IWRD_RTC"
# [158] "ListSort_Unadj"
# [159] "ListSort_AgeAdj"
# [160] "CogFluidComp_Unadj"
# [161] "CogFluidComp_AgeAdj"
# [162] "CogEarlyComp_Unadj"
# [163] "CogEarlyComp_AgeAdj"
# [164] "CogTotalComp_Unadj"
# [165] "CogTotalComp_AgeAdj"
# [166] "CogCrystalComp_Unadj"
# [167] "CogCrystalComp_AgeAdj"
# [168] "ER40_CR"
# [169] "ER40_CRT"
# [170] "ER40ANG"
# [171] "ER40FEAR"
# [172] "ER40HAP"
# [173] "ER40NOE"
# [174] "ER40SAD"
# [175] "AngAffect_Unadj"
# [176] "AngHostil_Unadj"
# [177] "AngAggr_Unadj"
# [178] "FearAffect_Unadj"
# [179] "FearSomat_Unadj"
# [180] "Sadness_Unadj"
# [181] "LifeSatisf_Unadj"
# [182] "MeanPurp_Unadj"
# [183] "PosAffect_Unadj"
# [184] "Friendship_Unadj"
# [185] "Loneliness_Unadj"
# [186] "PercHostil_Unadj"
# [187] "PercReject_Unadj"
# [188] "EmotSupp_Unadj"
# [189] "InstruSupp_Unadj"
# [190] "PercStress_Unadj"
# [191] "SelfEff_Unadj"
# [192] "FS_IntraCranial_Vol"
# [193] "FS_BrainSeg_Vol"
# [194] "FS_BrainSeg_Vol_No_Vent"
# [195] "FS_BrainSeg_Vol_No_Vent_Surf"
# [196] "FS_LCort_GM_Vol"
# [197] "FS_RCort_GM_Vol"
# [198] "FS_TotCort_GM_Vol"
# [199] "FS_SubCort_GM_Vol"
# [200] "FS_Total_GM_Vol"
# [201] "FS_SupraTentorial_Vol"
# [202] "FS_L_WM_Vol"
# [203] "FS_R_WM_Vol"
# [204] "FS_Tot_WM_Vol"
# [205] "FS_Mask_Vol"
# [206] "FS_BrainSegVol_eTIV_Ratio"
# [207] "FS_MaskVol_eTIV_Ratio"
# [208] "FS_LH_Defect_Holes"
# [209] "FS_RH_Defect_Holes"
# [210] "FS_Total_Defect_Holes"
# [211] "FS_L_LatVent_Vol"
# [212] "FS_L_InfLatVent_Vol"
# [213] "FS_L_Cerebellum_WM_Vol"
# [214] "FS_L_Cerebellum_Cort_Vol"
# [215] "FS_L_ThalamusProper_Vol"
# [216] "FS_L_Caudate_Vol"
# [217] "FS_L_Putamen_Vol"
# [218] "FS_L_Pallidum_Vol"
# [219] "FS_3rdVent_Vol"
# [220] "FS_4thVent_Vol"
# [221] "FS_BrainStem_Vol"
# [222] "FS_L_Hippo_Vol"
# [223] "FS_L_Amygdala_Vol"
# [224] "FS_CSF_Vol"
# [225] "FS_L_AccumbensArea_Vol"
# [226] "FS_L_VentDC_Vol"
# [227] "FS_L_Vessel_Vol"
# [228] "FS_L_ChoroidPlexus_Vol"
# [229] "FS_R_LatVent_Vol"
# [230] "FS_R_InfLatVent_Vol"
# [231] "FS_R_Cerebellum_WM_Vol"
# [232] "FS_R_Cerebellum_Cort_Vol"
# [233] "FS_R_ThalamusProper_Vol"
# [234] "FS_R_Caudate_Vol"
# [235] "FS_R_Putamen_Vol"
# [236] "FS_R_Pallidum_Vol"
# [237] "FS_R_Hippo_Vol"
# [238] "FS_R_Amygdala_Vol"
# [239] "FS_R_AccumbensArea_Vol"
# [240] "FS_R_VentDC_Vol"
# [241] "FS_R_Vessel_Vol"
# [242] "FS_R_ChoroidPlexus_Vol"
# [243] "FS_5thVent_Vol"
# [244] "FS_WM_Hypointens_Vol"
# [245] "FS_L_WM_Hypointens_Vol"
# [246] "FS_R_WM_Hypointens_Vol"
# [247] "FS_L_Non.WM_Hypointens_Vol"
# [248] "FS_R_Non.WM_Hypointens_Vol"
# [249] "FS_OpticChiasm_Vol"
# [250] "FS_CC_Posterior_Vol"
# [251] "FS_CC_MidPosterior_Vol"
# [252] "FS_CC_Central_Vol"
# [253] "FS_CC_MidAnterior_Vol"
# [254] "FS_CC_Anterior_Vol"
# [255] "FS_L_Bankssts_Thck"
# [256] "FS_L_Caudalanteriorcingulate_Thck"
# [257] "FS_L_Caudalmiddlefrontal_Thck"
# [258] "FS_L_Cuneus_Thck"
# [259] "FS_L_Entorhinal_Thck"
# [260] "FS_L_Fusiform_Thck"
# [261] "FS_L_Inferiorparietal_Thck"
# [262] "FS_L_Inferiortemporal_Thck"
# [263] "FS_L_Isthmuscingulate_Thck"
# [264] "FS_L_Lateraloccipital_Thck"
# [265] "FS_L_Lateralorbitofrontal_Thck"
# [266] "FS_L_Lingual_Thck"
# [267] "FS_L_Medialorbitofrontal_Thck"
# [268] "FS_L_Middletemporal_Thck"
# [269] "FS_L_Parahippocampal_Thck"
# [270] "FS_L_Paracentral_Thck"
# [271] "FS_L_Parsopercularis_Thck"
# [272] "FS_L_Parsorbitalis_Thck"
# [273] "FS_L_Parstriangularis_Thck"
# [274] "FS_L_Pericalcarine_Thck"
# [275] "FS_L_Postcentral_Thck"
# [276] "FS_L_Posteriorcingulate_Thck"
# [277] "FS_L_Precentral_Thck"
# [278] "FS_L_Precuneus_Thck"
# [279] "FS_L_Rostralanteriorcingulate_Thck"
# [280] "FS_L_Rostralmiddlefrontal_Thck"
# [281] "FS_L_Superiorfrontal_Thck"
# [282] "FS_L_Superiorparietal_Thck"
# [283] "FS_L_Superiortemporal_Thck"
# [284] "FS_L_Supramarginal_Thck"
# [285] "FS_L_Frontalpole_Thck"
# [286] "FS_L_Temporalpole_Thck"
# [287] "FS_L_Transversetemporal_Thck"
# [288] "FS_L_Insula_Thck"
# [289] "FS_R_Bankssts_Thck"
# [290] "FS_R_Caudalanteriorcingulate_Thck"
# [291] "FS_R_Caudalmiddlefrontal_Thck"
# [292] "FS_R_Cuneus_Thck"
# [293] "FS_R_Entorhinal_Thck"
# [294] "FS_R_Fusiform_Thck"
# [295] "FS_R_Inferiorparietal_Thck"
# [296] "FS_R_Inferiortemporal_Thck"
# [297] "FS_R_Isthmuscingulate_Thck"
# [298] "FS_R_Lateraloccipital_Thck"
# [299] "FS_R_Lateralorbitofrontal_Thck"
# [300] "FS_R_Lingual_Thck"
# [301] "FS_R_Medialorbitofrontal_Thck"
# [302] "FS_R_Middletemporal_Thck"
# [303] "FS_R_Parahippocampal_Thck"
# [304] "FS_R_Paracentral_Thck"
# [305] "FS_R_Parsopercularis_Thck"
# [306] "FS_R_Parsorbitalis_Thck"
# [307] "FS_R_Parstriangularis_Thck"
# [308] "FS_R_Pericalcarine_Thck"
# [309] "FS_R_Postcentral_Thck"
# [310] "FS_R_Posteriorcingulate_Thck"
# [311] "FS_R_Precentral_Thck"
# [312] "FS_R_Precuneus_Thck"
# [313] "FS_R_Rostralanteriorcingulate_Thck"
# [314] "FS_R_Rostralmiddlefrontal_Thck"
# [315] "FS_R_Superiorfrontal_Thck"
# [316] "FS_R_Superiorparietal_Thck"
# [317] "FS_R_Superiortemporal_Thck"
# [318] "FS_R_Supramarginal_Thck"
# [319] "FS_R_Frontalpole_Thck"
# [320] "FS_R_Temporalpole_Thck"
# [321] "FS_R_Transversetemporal_Thck"
# [322] "FS_R_Insula_Thck"
# [323] "FS_L_Bankssts_Area"
# [324] "FS_L_Caudalanteriorcingulate_Area"
# [325] "FS_L_Caudalmiddlefrontal_Area"
# [326] "FS_L_Cuneus_Area"
# [327] "FS_L_Entorhinal_Area"
# [328] "FS_L_Fusiform_Area"
# [329] "FS_L_Inferiorparietal_Area"
# [330] "FS_L_Inferiortemporal_Area"
# [331] "FS_L_Isthmuscingulate_Area"
# [332] "FS_L_Lateraloccipital_Area"
# [333] "FS_L_Lateralorbitofrontal_Area"
# [334] "FS_L_Lingual_Area"
# [335] "FS_L_Medialorbitofrontal_Area"
# [336] "FS_L_Middletemporal_Area"
# [337] "FS_L_Parahippocampal_Area"
# [338] "FS_L_Paracentral_Area"
# [339] "FS_L_Parsopercularis_Area"
# [340] "FS_L_Parsorbitalis_Area"
# [341] "FS_L_Parstriangularis_Area"
# [342] "FS_L_Pericalcarine_Area"
# [343] "FS_L_Postcentral_Area"
# [344] "FS_L_Posteriorcingulate_Area"
# [345] "FS_L_Precentral_Area"
# [346] "FS_L_Precuneus_Area"
# [347] "FS_L_Rostralanteriorcingulate_Area"
# [348] "FS_L_Rostralmiddlefrontal_Area"
# [349] "FS_L_Superiorfrontal_Area"
# [350] "FS_L_Superiorparietal_Area"
# [351] "FS_L_Superiortemporal_Area"
# [352] "FS_L_Supramarginal_Area"
# [353] "FS_L_Frontalpole_Area"
# [354] "FS_L_Temporalpole_Area"
# [355] "FS_L_Transversetemporal_Area"
# [356] "FS_L_Insula_Area"
# [357] "FS_R_Bankssts_Area"
# [358] "FS_R_Caudalanteriorcingulate_Area"
# [359] "FS_R_Caudalmiddlefrontal_Area"
# [360] "FS_R_Cuneus_Area"
# [361] "FS_R_Entorhinal_Area"
# [362] "FS_R_Fusiform_Area"
# [363] "FS_R_Inferiorparietal_Area"
# [364] "FS_R_Inferiortemporal_Area"
# [365] "FS_R_Isthmuscingulate_Area"
# [366] "FS_R_Lateraloccipital_Area"
# [367] "FS_R_Lateralorbitofrontal_Area"
# [368] "FS_R_Lingual_Area"
# [369] "FS_R_Medialorbitofrontal_Area"
# [370] "FS_R_Middletemporal_Area"
# [371] "FS_R_Parahippocampal_Area"
# [372] "FS_R_Paracentral_Area"
# [373] "FS_R_Parsopercularis_Area"
# [374] "FS_R_Parsorbitalis_Area"
# [375] "FS_R_Parstriangularis_Area"
# [376] "FS_R_Pericalcarine_Area"
# [377] "FS_R_Postcentral_Area"
# [378] "FS_R_Posteriorcingulate_Area"
# [379] "FS_R_Precentral_Area"
# [380] "FS_R_Precuneus_Area"
# [381] "FS_R_Rostralanteriorcingulate_Area"
# [382] "FS_R_Rostralmiddlefrontal_Area"
# [383] "FS_R_Superiorfrontal_Area"
# [384] "FS_R_Superiorparietal_Area"
# [385] "FS_R_Superiortemporal_Area"
# [386] "FS_R_Supramarginal_Area"
# [387] "FS_R_Frontalpole_Area"
# [388] "FS_R_Temporalpole_Area"
# [389] "FS_R_Transversetemporal_Area"
# [390] "FS_R_Insula_Area"
# [391] "Emotion_Task_Acc"
# [392] "Emotion_Task_Median_RT"
# [393] "Emotion_Task_Face_Acc"
# [394] "Emotion_Task_Face_Median_RT"
# [395] "Emotion_Task_Shape_Acc"
# [396] "Emotion_Task_Shape_Median_RT"
# [397] "Gambling_Task_Perc_Larger"
# [398] "Gambling_Task_Perc_Smaller"
# [399] "Gambling_Task_Perc_NLR"
# [400] "Gambling_Task_Median_RT_Larger"
# [401] "Gambling_Task_Median_RT_Smaller"
# [402] "Gambling_Task_Reward_Perc_Larger"
# [403] "Gambling_Task_Reward_Median_RT_Larger"
# [404] "Gambling_Task_Reward_Perc_Smaller"
# [405] "Gambling_Task_Reward_Median_RT_Smaller"
# [406] "Gambling_Task_Reward_Perc_NLR"
# [407] "Gambling_Task_Punish_Perc_Larger"
# [408] "Gambling_Task_Punish_Median_RT_Larger"
# [409] "Gambling_Task_Punish_Perc_Smaller"
# [410] "Gambling_Task_Punish_Median_RT_Smaller"
# [411] "Gambling_Task_Punish_Perc_NLR"
# [412] "Language_Task_Acc"
# [413] "Language_Task_Median_RT"
# [414] "Language_Task_Story_Acc"
# [415] "Language_Task_Story_Median_RT"
# [416] "Language_Task_Story_Avg_Difficulty_Level"
# [417] "Language_Task_Math_Acc"
# [418] "Language_Task_Math_Median_RT"
# [419] "Language_Task_Math_Avg_Difficulty_Level"
# [420] "Relational_Task_Acc"
# [421] "Relational_Task_Median_RT"
# [422] "Relational_Task_Match_Acc"
# [423] "Relational_Task_Match_Median_RT"
# [424] "Relational_Task_Rel_Acc"
# [425] "Relational_Task_Rel_Median_RT"
# [426] "Social_Task_Perc_Random"
# [427] "Social_Task_Perc_TOM"
# [428] "Social_Task_Perc_Unsure"
# [429] "Social_Task_Perc_NLR"
# [430] "Social_Task_Median_RT_Random"
# [431] "Social_Task_Median_RT_TOM"
# [432] "Social_Task_Median_RT_Unsure"
# [433] "Social_Task_Random_Perc_Random"
# [434] "Social_Task_Random_Median_RT_Random"
# [435] "Social_Task_Random_Perc_TOM"
# [436] "Social_Task_Random_Median_RT_TOM"
# [437] "Social_Task_Random_Perc_Unsure"
# [438] "Social_Task_Random_Median_RT_Unsure"
# [439] "Social_Task_Random_Perc_NLR"
# [440] "Social_Task_TOM_Perc_Random"
# [441] "Social_Task_TOM_Median_RT_Random"
# [442] "Social_Task_TOM_Perc_TOM"
# [443] "Social_Task_TOM_Median_RT_TOM"
# [444] "Social_Task_TOM_Perc_Unsure"
# [445] "Social_Task_TOM_Median_RT_Unsure"
# [446] "Social_Task_TOM_Perc_NLR"
# [447] "WM_Task_Acc"
# [448] "WM_Task_Median_RT"
# [449] "WM_Task_2bk_Acc"
# [450] "WM_Task_2bk_Median_RT"
# [451] "WM_Task_0bk_Acc"
# [452] "WM_Task_0bk_Median_RT"
# [453] "WM_Task_0bk_Body_Acc"
# [454] "WM_Task_0bk_Body_Acc_Target"
# [455] "WM_Task_0bk_Body_Acc_Nontarget"
# [456] "WM_Task_0bk_Face_Acc"
# [457] "WM_Task_0bk_Face_Acc_Target"
# [458] "WM_Task_0bk_Face_ACC_Nontarget"
# [459] "WM_Task_0bk_Place_Acc"
# [460] "WM_Task_0bk_Place_Acc_Target"
# [461] "WM_Task_0bk_Place_Acc_Nontarget"
# [462] "WM_Task_0bk_Tool_Acc"
# [463] "WM_Task_0bk_Tool_Acc_Target"
# [464] "WM_Task_0bk_Tool_Acc_Nontarget"
# [465] "WM_Task_2bk_Body_Acc"
# [466] "WM_Task_2bk_Body_Acc_Target"
# [467] "WM_Task_2bk_Body_Acc_Nontarget"
# [468] "WM_Task_2bk_Face_Acc"
# [469] "WM_Task_2bk_Face_Acc_Target"
# [470] "WM_Task_2bk_Face_Acc_Nontarget"
# [471] "WM_Task_2bk_Place_Acc"
# [472] "WM_Task_2bk_Place_Acc_Target"
# [473] "WM_Task_2bk_Place_Acc_Nontarget"
# [474] "WM_Task_2bk_Tool_Acc"
# [475] "WM_Task_2bk_Tool_Acc_Target"
# [476] "WM_Task_2bk_Tool_Acc_Nontarget"
# [477] "WM_Task_0bk_Body_Median_RT"
# [478] "WM_Task_0bk_Body_Median_RT_Target"
# [479] "WM_Task_0bk_Body_Median_RT_Nontarget"
# [480] "WM_Task_0bk_Face_Median_RT"
# [481] "WM_Task_0bk_Face_Median_RT_Target"
# [482] "WM_Task_0bk_Face_Median_RT_Nontarget"
# [483] "WM_Task_0bk_Place_Median_RT"
# [484] "WM_Task_0bk_Place_Median_RT_Target"
# [485] "WM_Task_0bk_Place_Median_RT_Nontarget"
# [486] "WM_Task_0bk_Tool_Median_RT"
# [487] "WM_Task_0bk_Tool_Median_RT_Target"
# [488] "WM_Task_0bk_Tool_Median_RT_Nontarget"
# [489] "WM_Task_2bk_Body_Median_RT"
# [490] "WM_Task_2bk_Body_Median_RT_Target"
# [491] "WM_Task_2bk_Body_Median_RT_Nontarget"
# [492] "WM_Task_2bk_Face_Median_RT"
# [493] "WM_Task_2bk_Face_Median_RT_Target"
# [494] "WM_Task_2bk_Face_Median_RT_Nontarget"
# [495] "WM_Task_2bk_Place_Median_RT"
# [496] "WM_Task_2bk_Place_Median_RT_Target"
# [497] "WM_Task_2bk_Place_Median_RT_Nontarget"
# [498] "WM_Task_2bk_Tool_Median_RT"
# [499] "WM_Task_2bk_Tool_Median_RT_Target"
# [500] "WM_Task_2bk_Tool_Median_RT_Nontarget"
# [501] "Endurance_Unadj"
# [502] "Endurance_AgeAdj"
# [503] "GaitSpeed_Comp"
# [504] "Dexterity_Unadj"
# [505] "Dexterity_AgeAdj"
# [506] "Strength_Unadj"
# [507] "Strength_AgeAdj"
# [508] "NEOFAC_A"
# [509] "NEOFAC_O"
# [510] "NEOFAC_C"
# [511] "NEOFAC_N"
# [512] "NEOFAC_E"
# [513] "NEORAW_01"
# [514] "NEORAW_02"
# [515] "NEORAW_03"
# [516] "NEORAW_04"
# [517] "NEORAW_05"
# [518] "NEORAW_06"
# [519] "NEORAW_07"
# [520] "NEORAW_08"
# [521] "NEORAW_09"
# [522] "NEORAW_10"
# [523] "NEORAW_11"
# [524] "NEORAW_12"
# [525] "NEORAW_13"
# [526] "NEORAW_14"
# [527] "NEORAW_15"
# [528] "NEORAW_16"
# [529] "NEORAW_17"
# [530] "NEORAW_18"
# [531] "NEORAW_19"
# [532] "NEORAW_20"
# [533] "NEORAW_21"
# [534] "NEORAW_22"
# [535] "NEORAW_23"
# [536] "NEORAW_24"
# [537] "NEORAW_25"
# [538] "NEORAW_26"
# [539] "NEORAW_27"
# [540] "NEORAW_28"
# [541] "NEORAW_29"
# [542] "NEORAW_30"
# [543] "NEORAW_31"
# [544] "NEORAW_32"
# [545] "NEORAW_33"
# [546] "NEORAW_34"
# [547] "NEORAW_35"
# [548] "NEORAW_36"
# [549] "NEORAW_37"
# [550] "NEORAW_38"
# [551] "NEORAW_39"
# [552] "NEORAW_40"
# [553] "NEORAW_41"
# [554] "NEORAW_42"
# [555] "NEORAW_43"
# [556] "NEORAW_44"
# [557] "NEORAW_45"
# [558] "NEORAW_46"
# [559] "NEORAW_47"
# [560] "NEORAW_48"
# [561] "NEORAW_49"
# [562] "NEORAW_50"
# [563] "NEORAW_51"
# [564] "NEORAW_52"
# [565] "NEORAW_53"
# [566] "NEORAW_54"
# [567] "NEORAW_55"
# [568] "NEORAW_56"
# [569] "NEORAW_57"
# [570] "NEORAW_58"
# [571] "NEORAW_59"
# [572] "NEORAW_60"
# [573] "Noise_Comp"
# [574] "Odor_Unadj"
# [575] "Odor_AgeAdj"
# [576] "PainIntens_RawScore"
# [577] "PainInterf_Tscore"
# [578] "Taste_Unadj"
# [579] "Taste_AgeAdj"
# [580] "Mars_Log_Score"
# [581] "Mars_Errs"
# [582] "Mars_Final"

# %% [markdown]
# __Import data dictionary__

# %%
data_dict <- read.csv('/Users/Administrator/Downloads/HCP_S1200_DataDictionary_April_20_2018.csv')
data_dict
# Out:
#     fullDisplayName                              category
# 1   Subject                                      Subject Information
# 2   Quarter Released                             Subject Information
# 3   Acquisition Quarter                          Subject Information
# 4   Gender                                       Subject Information
# 5   Age Range                                    Subject Information
# 6   Age Range                                    Subject Information
# 7   Age Range                                    Subject Information
# 8   Age in Years                                 Subject Information
# 9   HasGT                                        Subject Information
# 10  ZygositySR                                   Subject Information
# 11  ZygosityGT                                   Subject Information
# 12  FamilyID                                     Subject Information
# 13  Mother ID                                    Subject Information
# 14  Father ID                                    Subject Information
# 15  TestRetestInterval                           Subject Information
# 16  Race                                         Subject Information
# 17  Ethnicity                                    Subject Information
# 18  Handedness                                   Subject Information
# 19  Employment Status                            Subject Information
# 20  Household Income                             Subject Information
# 21  Education                                    Subject Information
# 22  Still in School                              Subject Information
# 23  Relationship Status                          Subject Information
# 24  Missouri Born                                Subject Information
# 25  Full 3T Imaging Protocol Completed           Study Completion
# 26  T1 Scan Count                                Study Completion
# 27  T2 Scan Count                                Study Completion
# 28  3T Resting State fMRI Count                  Study Completion
# 29  3T Resting State fMRI Percent Complete       Study Completion
# 30  Full 3T Task fMRI Protocol Completed         Study Completion
# ... ...                                          ...
# 784 Whether age last smoked is current age       Substance Use
# 785 Years since respondent smoked last cigarette Substance Use
# 786 Years smoked                                 Substance Use
# 787 Times used illicit drugs                     Substance Use
# 788 Times used cocaine                           Substance Use
# 789 Times used hallucinogens                     Substance Use
# 790 Times used opiates                           Substance Use
# 791 Times used sedatives                         Substance Use
# 792 Times used stimulants                        Substance Use
# 793 Ever used marijuana?                         Substance Use
# 794 DSM Marijuana Dependence                     Substance Use
# 795 Age at first marijuana use                   Substance Use
# 796 Times used marijuana                         Substance Use
# 797 trackfrac                                    7T Eye Tracker Metadata
# 798 TRfrac                                       7T Eye Tracker Metadata
# 799 RET trackfrac min                            7T Eye Tracker Metadata
# 800 RET TRfrac min                               7T Eye Tracker Metadata
# 801 RET eyetrack complete                        7T Eye Tracker Metadata
# 802 MOV1 trackfrac                               7T Eye Tracker Metadata
# 803 MOV1 TRfrac                                  7T Eye Tracker Metadata
# 804 MOV2 trackfrac                               7T Eye Tracker Metadata
# 805 MOV2 TRfrac                                  7T Eye Tracker Metadata
# 806 MOV3 trackfrac                               7T Eye Tracker Metadata
# 807 MOV3 TRfrac                                  7T Eye Tracker Metadata
# 808 MOV4 trackfrac                               7T Eye Tracker Metadata
# 809 MOV4 TRfrac                                  7T Eye Tracker Metadata
# 810 MOV eyetrack compl                           7T Eye Tracker Metadata
# 811 REST trackfrac min                           7T Eye Tracker Metadata
# 812 REST TRfrac min                              7T Eye Tracker Metadata
# 813 REST eyetrack compl                          7T Eye Tracker Metadata
#     assessment                   columnHeader
# 1   Demographics                 Subject
# 2   Demographics                 Release
# 3   Demographics                 Acquisition
# 4   Demographics                 Gender
# 5   Demographics                 Age
# 6   Demographics                 Age
# 7   Demographics                 Age
# 8   Demographics                 Age_in_Yrs
# 9   Demographics                 HasGT
# 10  Demographics                 ZygositySR
# 11  Demographics                 ZygosityGT
# 12  Demographics                 Family_ID
# 13  Demographics                 Mother_ID
# 14  Demographics                 Father_ID
# 15  Demographics                 TestRetestInterval
# 16  Demographics                 Race
# 17  Demographics                 Ethnicity
# 18  Demographics                 Handedness
# 19  Demographics                 SSAGA_Employ
# 20  Demographics                 SSAGA_Income
# 21  Demographics                 SSAGA_Educ
# 22  Demographics                 SSAGA_InSchool
# 23  Demographics                 SSAGA_Rlshp
# 24  Demographics                 SSAGA_MOBorn
# 25  Study Completion: 3T MR      3T_Full_MR_Compl
# 26  Study Completion: 3T MR      T1_Count
# 27  Study Completion: 3T MR      T2_Count
# 28  Study Completion: 3T MR      3T_RS-fMRI_Count
# 29  Study Completion: 3T MR      3T_RS-fMRI_PctCompl
# 30  Study Completion: 3T MR      3T_Full_Task_fMRI
# ... ...                          ...
# 784 Tobacco Use and Dependence   SSAGA_TB_Still_Smoking
# 785 Tobacco Use and Dependence   SSAGA_TB_Yrs_Since_Quit
# 786 Tobacco Use and Dependence   SSAGA_TB_Yrs_Smoked
# 787 Illicit Drug Use             SSAGA_Times_Used_Illicits
# 788 Illicit Drug Use             SSAGA_Times_Used_Cocaine
# 789 Illicit Drug Use             SSAGA_Times_Used_Hallucinogens
# 790 Illicit Drug Use             SSAGA_Times_Used_Opiates
# 791 Illicit Drug Use             SSAGA_Times_Used_Sedatives
# 792 Illicit Drug Use             SSAGA_Times_Used_Stimulants
# 793 Marijuana Use and Dependence SSAGA_Mj_Use
# 794 Marijuana Use and Dependence SSAGA_Mj_Ab_Dep
# 795 Marijuana Use and Dependence SSAGA_Mj_Age_1st_Use
# 796 Marijuana Use and Dependence SSAGA_Mj_Times_Used
# 797 Percentages                  TRACKFRAC
# 798 Percentages                  TRFAC
# 799 RET                          RET_TRACKFRAC_MIN
# 800 RET                          RET_TRFRAC_MIN
# 801 RET                          RET_EYETRACK_COMPL
# 802 MOV                          MOV1_TRACKFRAC
# 803 MOV                          MOV1_TRFRAC
# 804 MOV                          MOV2_TRACKFRAC
# 805 MOV                          MOV2_TRFRAC
# 806 MOV                          MOV3_TRACKFRAC
# 807 MOV                          MOV3_TRFRAC
# 808 MOV                          MOV4_TRACKFRAC
# 809 MOV                          MOV4_TRFRAC
# 810 MOV                          MOV_EYETRACK_COMPL
# 811 REST                         REST_TRACKFRAC_MIN
# 812 REST                         REST_TRFRAC_MIN
# 813 REST                         REST_EYETRACK_COMPL
#     description
# 1   HCP Subject ID
# 2   HCP data release in which this subject's data was initially published to ConnectomeDB.   Note: 'Release' does not indicate the version of the pipelines used to process subject data. Check the release-notes distributed with each processed dataset for pipeline version information.
# 3   Quarter in which this subject's data was initially acquired.
# 4   Gender of Subject
# 5   Age group of Participant, banded in five-year increments.
# 6   Age group of Participant.
# 7   Age group of Participant.
# 8   Age of Participant in Years
# 9   Genotyping data available from at least one of the 2 gene chips used: (1) Illumina Mega Chip plus content from the Illumina ImmunoArray and PsychArray; (2) Illumina Neuro Consortium Array.   Family structure (i.e., Mother_ID and Father_ID) is genetically verified for pairs of siblings (includings twins and half-silbings) for whom HasGT=TRUE
# 10  Self-reported zygosity. Until the S1200 release this was the \\Zygosity\\" measure. The small number of subjects who do not have a value for this measure (blank) self reported as twins but did not self report their twin zygosity."
# 11  Twin zygosity verified by genotyping. Requires both subjects in a twin pair to have HasGT=TRUE to have a value (if genotyping is not available for either of a twin pair, no values are given for ZygosityGT).  Non-twin subjects also do not have a value for ZygosityGT.  Note that some subjects self-reported as dizygotic twins (ZygositySR='NotMZ') but genotyping established that they were monozygotic twins (thence ZygosityGT='MZ' for those subjects).  ZygosityGT should be given precedence over ZygositySR.
# 12  Lists all Mother_IDs and Father_IDs associated with subjects who share at least one parent. Family_ID does not indicate that siblings grew up in the same household/rearing environment.
# 13  Mother's study ID, based on genotyping between sibling subjects that both have HasGT=TRUE, otherwise is based on self report. Prior to the S1200 release, Mother_ID was based strictly on self-report.  Mother_IDs that have been changed in the S1200 release based on the genotyping released have a 999xx ID number
# 14  Father's study ID, based on genotyping between sibling subjects that both have HasGT=TRUE, otherwise is based on self report. Prior to the S1200 release, Father_ID was based strictly on self-report.  Father_IDs that have been changed in the S1200 release based on the genotyping released have a 999xx ID number
# 15  Time interval in days between the first scan session of subject's study \\Test\\" visit in the main HCP project and the first scan session of their \\"Retest\\" visit."
# 16  Self reported racial identification
# 17  Self reported ethnicity
# 18  Handedness of participant from -100 to 100 assessed using the Edinburgh Handedness questionnaire [Oldfield RC (1971). The assessment and analysis of handedness: The Edinburgh inventory. Neuropsychologia, 9(1): 97-113.]. Negative numbers indicate that a subject is more left-handed than right-handed, while positive numbers indicate that a subject is more right-handed than left-handed. See Schachter et al., Associations of handedness with hair color and learning disabilities. Neuropsychologia, 25:269-276, 1987. for more information on how these laterality scores are calculated.
# 19  Participant's employment status: not working = 0, part-time employment = 1; full-time employment = 2
# 20  Total household income: <$10,000 = 1,10K-19,999 = 2, 20K-29,999 = 3,30K-39,999 = 4, 40K-49,999 = 5, 50K-74,999 = 6, 75K-99,999 = 7, >=100,000 = 8
# 21  Years of education completed: <11 = 11; 12; 13; 14; 15; 16; 17+ = 17
# 22  Is respondent still in school for degree course? no = 0; yes = 1
# 23  Is respondent married or in live-in relationship? no = 0; yes = 1
# 24  Is respondent Missouri born? no = 0; yes = 1
# 25  Full HCP 3T MRI protocol was completed, all scans, all timepoints (True or False)
# 26  Number of T1 scans collected
# 27  Number of T2 scans collected
# 28  Number of 3T resting state scans collected
# 29  Percentage of 3T Resting State fMRI Scans Complete (100%=4800 timepoints)
# 30  Full 3T task fMRI protocol was completed, all scans, all timepoints (True or False)
# ... ...
# 784 Is the participant still smoking?: no = 0; yes = 1
# 785 Years since respondent smoked last cigarette (0 = still smoking; 1 = less than a year; 2 = 1 or more years)
# 786 Years smoked (1-5 years = 5; 6-10 = 10; 11-15 = 15; 16+ = 18)
# 787 Times used all classes of non-marijuana illicit drugs, including cocaine, hallucinogens, opiates, sedatives, or other: never used = 0; 1-2 times = 1; 3-10 times = 2; 11-25 times = 3; 26-100 times, if male= 4; >25 times = 4, if female; >100 times = 5, if male
# 788 Times used cocaine: never used = 0, 1-2 = 1, 3-5 = 1, 6-10 = 5, >10 = 5
# 789 Times used hallucinogens: never used = 0, 1-2 = 1, 3-5 = 2, 6-10 = 2, >10 = 5
# 790 Times used opiates: never used = 0, 1-2 = 1, 3-5 = 1, 6-10 = 5, >10 = 5
# 791 Times used sedatives: never used = 0, 1-2 = 1, 3-5 = 1, 6-10 = 5, >10 = 5
# 792 Times used stimulants: never used = 0, 1-2 = 1, 3-5 = 1, 6-10 = 1, >10 = 5
# 793 Ever used marijuana?: no = 0; yes = 1
# 794 Participant meets/met DSM criteria for Marijuana Dependence at some time over his/her lifetime?  no = 0; yes = 1
# 795 Age at first marijuana use: <=14 = 1; 15-17 = 2; 18-20 = 3; >=21 = 4
# 796 Times used marijuana: never used = 0; 1-5 = 1; 6-10 = 2; 11-25 = 3; 26-50 = 3; 51-100 = 3; 101-999 = 4; 1000-2000 = 5; >2000 = 5
# 797 Percentage of the scan that had Eye Tracker Metadata collected
# 798 Percentage of the total scan time that had TRs collected
# 799 The minimum value for Trackfrac (percentage of the scan that had Eye Tracker Metadata collected) among the subject's 6 retinotopy runs
# 800 The minimum value for TRfrac (percentage of total scan time that had TRs collected) among the subject's 6 retinotopy runs
# 801 TRfrac (percentage of total scan time that had TRs collected) value for all retinotopy scans is 100%
# 802 The value of Trackfrac (percentage of the scan that had Eye Tracker Metadata collected) for the Movie 1 scan
# 803 The value of TRfrac (percentage of total scan time that had TRs collected) for the Movie 1 scan
# 804 The value of Trackfrac (percentage of the scan that had Eye Tracker Metadata collected) for the Movie 2 scan
# 805 The value of TRfrac (percentage of total scan time that had TRs collected) for the Movie 2 scan
# 806 The value of Trackfrac (percentage of the scan that had Eye Tracker Metadata collected) for the Movie 3 scan
# 807 The value of TRfrac (percentage of total scan time that had TRs collected) for the Movie 3 scan
# 808 The value of Trackfrac (percentage of the scan that had Eye Tracker Metadata collected) for the Movie 4 scan
# 809 The value of TRfrac (percentage of total scan time that had TRs collected) for the Movie 4 scan
# 810 TRfrac (percentage of total scan time that had TRs collected) value for all movie scans is 100%
# 811 The minimum value for Trackfrac (percentage of the scan that had Eye Tracker Metadata collected) among the subject's 4 resting state runs
# 812 The minimum value for TRfrac (percentage of total scan time that had TRs collected) among the subject's 4 resting state runs
# 813 TRfrac (percentage of total scan time that had TRs collected) value for all resting state scans is 100%

# %% [markdown]
# Find revelant information about a variable in the data dictionary

# %%
data_dict[data_dict$columnHeader == 'PSQI_Bathroom',]
#dplyr::filter(data_dict, grepl('PSQI', columnHeader))
# Out:
#     fullDisplayName                            category
# 178 5c. Sleep Trouble - Get up to use bathroom Alertness
#     assessment                             columnHeader
# 178 Sleep (Pittsburgh Sleep Questionnaire) PSQI_Bathroom
#     description
# 178 PSQI 5.During the past month, how often have you had trouble sleeping because you...  (c) Have to get up to use the bathroom; 0=Not during the past month, 1=Less than once a week, 2=Once or twice a week, 3=3 or more times a week

# %% [markdown]
# #### Filtering a dataframe

# %%
psqi_vars <- filter(data_dict, grepl('PSQI', columnHeader))
psqi_vars <- psqi_vars$columnHeader
psqi_data <- select(filter(behav_data),psqi_vars)

head(psqi_data)
# Out:
#   PSQI_Compl PSQI_Score PSQI_Comp1 PSQI_Comp2 PSQI_Comp3 PSQI_Comp4 PSQI_Comp5
# 1 true       8          1          2          2          1          1
# 2 true       6          1          1          1          1          1
# 3 true       4          1          0          1          0          2
# 4 true       4          1          1          0          0          1
# 5 true       4          1          1          0          0          1
# 6 true       2          1          1          0          0          0
#   PSQI_Comp6 PSQI_Comp7 PSQI_BedTime ... PSQI_TooCold PSQI_TooHot PSQI_BadDream
# 1 0          1          09:00:00     ... 0            1           0
# 2 0          1          22:30:00     ... 0            1           0
# 3 0          0          22:00:00     ... 0            1           0
# 4 0          1          22:00:00     ... 0            0           0
# 5 0          1          21:30:00     ... 0            1           0
# 6 0          0          23:00:00     ... 0            0           0
#   PSQI_Pain PSQI_Other PSQI_Quality PSQI_SleepMeds PSQI_DayStayAwake
# 1 0         0          1            0              0
# 2 0         1          1            0              1
# 3 0         3          1            0              0
# 4 0         0          1            0              0
# 5 0         0          1            0              0
# 6 0         0          1            0              0
#   PSQI_DayEnthusiasm PSQI_BedPtnrRmate
# 1 2                  0
# 2 1                  0
# 3 0                  3
# 4 1                  3
# 5 1                  0
# 6 0                  3

# %%
add_vars <- c('Age','AngAffect_Unadj')
add_data <- select(filter(behav_data),add_vars)
head(add_data)
# Out:
#   Age   AngAffect_Unadj
# 1 22-25 49.3
# 2 26-30 54.8
# 3 26-30 46.9
# 4 31-35 50.6
# 5 26-30 47.5
# 6 31-35 59.0

# %% [markdown]
# __Combine dataframes__

# %%
relv_data <- cbind(add_data, psqi_data)
summary(relv_data)
# Out:
#     Age      AngAffect_Unadj PSQI_Compl    PSQI_Score       PSQI_Comp1
#  22-25:247   Min.   :28.60   true:1206   Min.   : 0.000   Min.   :0.0000
#  26-30:527   1st Qu.:43.00               1st Qu.: 3.000   1st Qu.:1.0000
#  31-35:418   Median :48.40               Median : 4.000   Median :1.0000
#  36+  : 14   Mean   :48.03               Mean   : 4.855   Mean   :0.9038
#              3rd Qu.:53.10               3rd Qu.: 6.000   3rd Qu.:1.0000
#              Max.   :85.40               Max.   :19.000   Max.   :3.0000
#              NA's   :1
#    PSQI_Comp2       PSQI_Comp3       PSQI_Comp4      PSQI_Comp5
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.000   Min.   :0.000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.000   1st Qu.:1.000
#  Median :1.0000   Median :0.0000   Median :0.000   Median :1.000
#  Mean   :0.9818   Mean   :0.5755   Mean   :0.466   Mean   :1.105
#  3rd Qu.:1.0000   3rd Qu.:1.0000   3rd Qu.:1.000   3rd Qu.:1.000
#  Max.   :3.0000   Max.   :3.0000   Max.   :3.000   Max.   :3.000
#
#    PSQI_Comp6       PSQI_Comp7       PSQI_BedTime PSQI_Min2Asleep
#  Min.   :0.0000   Min.   :0.0000   23:00:00:218   Min.   :  0.00
#  1st Qu.:0.0000   1st Qu.:0.0000   22:00:00:187   1st Qu.: 10.00
#  Median :0.0000   Median :1.0000   22:30:00:155   Median : 15.00
#  Mean   :0.2355   Mean   :0.5871   00:00:00:132   Mean   : 20.38
#  3rd Qu.:0.0000   3rd Qu.:1.0000   23:30:00: 84   3rd Qu.: 30.00
#  Max.   :3.0000   Max.   :3.0000   21:30:00: 56   Max.   :300.00
#                                    (Other) :374
#   PSQI_GetUpTime PSQI_AmtSleep    PSQI_Latency30Min  PSQI_WakeUp
#  07:00:00:168    Min.   : 2.000   Min.   :0.0000    Min.   :0.000
#  06:00:00:167    1st Qu.: 6.000   1st Qu.:0.0000    1st Qu.:0.000
#  06:30:00:123    Median : 7.000   Median :1.0000    Median :1.000
#  08:00:00:100    Mean   : 6.819   Mean   :0.9842    Mean   :1.323
#  05:30:00: 69    3rd Qu.: 7.500   3rd Qu.:2.0000    3rd Qu.:2.000
#  07:30:00: 69    Max.   :12.000   Max.   :3.0000    Max.   :3.000
#  (Other) :510
#  PSQI_Bathroom     PSQI_Breathe      PSQI_Snore      PSQI_TooCold
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :1.0000   Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.9917   Mean   :0.1708   Mean   :0.3259   Mean   :0.4005
#  3rd Qu.:2.0000   3rd Qu.:0.0000   3rd Qu.:0.0000   3rd Qu.:1.0000
#  Max.   :3.0000   Max.   :3.0000   Max.   :3.0000   Max.   :3.0000
#
#   PSQI_TooHot     PSQI_BadDream      PSQI_Pain        PSQI_Other
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :1.0000   Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.7902   Mean   :0.3673   Mean   :0.2662   Mean   :0.9511
#  3rd Qu.:1.0000   3rd Qu.:1.0000   3rd Qu.:0.0000   3rd Qu.:2.0000
#  Max.   :3.0000   Max.   :3.0000   Max.   :3.0000   Max.   :3.0000
#
#   PSQI_Quality    PSQI_SleepMeds   PSQI_DayStayAwake PSQI_DayEnthusiasm
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000    Min.   :0.0000
#  1st Qu.:1.0000   1st Qu.:0.0000   1st Qu.:0.0000    1st Qu.:0.0000
#  Median :1.0000   Median :0.0000   Median :0.0000    Median :0.0000
#  Mean   :0.9038   Mean   :0.2355   Mean   :0.2488    Mean   :0.5605
#  3rd Qu.:1.0000   3rd Qu.:0.0000   3rd Qu.:0.0000    3rd Qu.:1.0000
#  Max.   :3.0000   Max.   :3.0000   Max.   :3.0000    Max.   :3.0000
#
#  PSQI_BedPtnrRmate
#  Min.   :0.000
#  1st Qu.:0.000
#  Median :3.000
#  Mean   :1.959
#  3rd Qu.:3.000
#  Max.   :3.000
#  NA's   :1

# %%
corr_results <- cor.test(relv_data$AngAffect_Unadj, relv_data$PSQI_Bathroom)
corr_results
# Out:
# 	Pearson's product-moment correlation
#
# data:  relv_data$AngAffect_Unadj and relv_data$PSQI_Bathroom
# t = 4.137, df = 1203, p-value = 3.763e-05
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.06238156 0.17374635
# sample estimates:
#       cor
# 0.1184364

# %%
print(paste0("Having trouble sleeping because of a need to use the bathroom is weakly correlated with angry affect (r = ", 
             round(corr_results$estimate, digits = 4),
            ", p = ",corr_results$p.value,")"))
# Out:
# [1] "Having trouble sleeping because of a need to use the bathroom is weakly correlated with angry affect (r = 0.1184, p = 3.76344677497135e-05)"

# %% [markdown]
# ***
# # HCP Freesurfer Structural Data

# %%
struct_data <- read.csv('/Users/Administrator/Downloads/unrestricted_hcp_freesurfer.csv')

head(struct_data)
# Out:
#   Subject Gender Release FS_InterCranial_Vol FS_BrainSeg_Vol
# 1 100206  M      S900    1864518             1406924
# 2 100307  F      Q1      1512540             1109710
# 3 100408  M      Q3      1684117             1280171
# 4 100610  M      S900    1816044             1321362
# 5 101006  F      S500    1437868             1053766
# 6 101107  M      S500    1512727             1126655
#   FS_BrainSeg_Vol_No_Vent FS_BrainSeg_Vol_No_Vent_Surf FS_LCort_GM_Vol
# 1 1389007                 1386836                      304488
# 2 1098854                 1097122                      240030
# 3 1260943                 1259250                      260695
# 4 1306929                 1304569                      276506
# 5 1038408                 1037793                      203718
# 6 1111763                 1109747                      242489
#   FS_RCort_GM_Vol FS_TotCort_GM_Vol ... FS_R_Rostralanteriorcingulate_CurvInd
# 1 305634          610122            ... 5.6
# 2 243207          483238            ... 3.3
# 3 265243          525938            ... 3.3
# 4 278002          554508            ... 3.0
# 5 210539          414257            ... 2.9
# 6 248807          491296            ... 3.9
#   FS_R_Rostralmiddlefrontal_CurvInd FS_R_Superiorfrontal_CurvInd
# 1 34.6                              40.1
# 2 29.9                              48.8
# 3 25.2                              27.5
# 4 19.6                              20.0
# 5 14.7                              21.3
# 6 17.5                              18.1
#   FS_R_Superiorparietal_CurvInd FS_R_Superiortemporal_CurvInd
# 1 23.3                          15.6
# 2 21.6                          18.6
# 3 15.2                          13.9
# 4 18.6                          10.6
# 5 13.2                           8.7
# 6  9.9                           6.7
#   FS_R_Supramarginal_CurvInd FS_R_Frontalpole_CurvInd FS_R_Temporalpole_CurvInd
# 1 11.9                       2.9                      3.8
# 2 15.0                       2.9                      5.8
# 3 12.3                       1.8                      7.8
# 4 10.8                       1.2                      4.1
# 5  9.8                       1.1                      3.0
# 6  7.2                       1.1                      2.3
#   FS_R_Transversetemporal_CurvInd FS_R_Insula_CurvInd
# 1 2.8                             37.5
# 2 2.0                             30.2
# 3 1.9                             25.1
# 4 1.4                             16.6
# 5 1.0                             18.9
# 6 0.9                             12.1

# %% [markdown]
# ### Filter dataframe

# %%
thick_vars <- grep('Thck', colnames(struct_data), value=TRUE)
thick_vars

# %%
thick_data <- select(filter(struct_data),thick_vars)

head(thick_data)
# Out:
# Note: Using an external vector in selections is ambiguous.
# i Use `all_of(thick_vars)` instead of `thick_vars` to silence this message.
# i See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#   FS_L_Bankssts_Thck FS_L_Caudalanteriorcingulate_Thck
# 1 2.733              2.682
# 2 2.713              3.253
# 3 2.532              2.588
# 4 2.683              3.029
# 5 2.632              2.657
# 6 2.877              2.729
#   FS_L_Caudalmiddlefrontal_Thck FS_L_Cuneus_Thck FS_L_Entorhinal_Thck
# 1 2.765                         2.185            3.388
# 2 2.795                         1.957            3.389
# 3 2.612                         2.127            3.310
# 4 2.735                         2.223            3.664
# 5 2.839                         1.977            3.236
# 6 2.851                         2.251            3.529
#   FS_L_Fusiform_Thck FS_L_Inferiorparietal_Thck FS_L_Inferiortemporal_Thck
# 1 2.957              2.583                      3.065
# 2 3.062              2.637                      2.968
# 3 2.870              2.515                      2.840
# 4 2.873              2.547                      3.062
# 5 2.841              2.522                      2.846
# 6 3.041              2.769                      3.123
#   FS_L_Isthmuscingulate_Thck FS_L_Lateraloccipital_Thck ...
# 1 2.428                      2.304                      ...
# 2 2.533                      2.259                      ...
# 3 2.257                      2.247                      ...
# 4 2.471                      2.238                      ...
# 5 2.300                      2.231                      ...
# 6 2.657                      2.529                      ...
#   FS_R_Rostralanteriorcingulate_ThckStd FS_R_Rostralmiddlefrontal_ThckStd
# 1 0.601                                 0.408
# 2 0.535                                 0.487
# 3 0.723                                 0.372
# 4 0.750                                 0.408
# 5 0.964                                 0.448
# 6 0.635                                 0.400
#   FS_R_Superiorfrontal_ThckStd FS_R_Superiorparietal_ThckStd
# 1 0.536                        0.348
# 2 0.628                        0.389
# 3 0.474                        0.328
# 4 0.548                        0.365
# 5 0.532                        0.375
# 6 0.491                        0.338
#   FS_R_Superiortemporal_ThckStd FS_R_Supramarginal_ThckStd
# 1 0.550                         0.428
# 2 0.532                         0.513
# 3 0.496                         0.366
# 4 0.543                         0.444
# 5 0.499                         0.471
# 6 0.616                         0.469
#   FS_R_Frontalpole_ThckStd FS_R_Temporalpole_ThckStd
# 1 0.545                    0.765
# 2 0.426                    0.517
# 3 0.316                    0.654
# 4 0.416                    0.586
# 5 0.254                    0.547
# 6 0.465                    0.610
#   FS_R_Transversetemporal_ThckStd FS_R_Insula_ThckStd
# 1 0.361                           0.794
# 2 0.339                           0.882
# 3 0.264                           0.864
# 4 0.268                           0.847
# 5 0.476                           0.795
# 6 0.395                           0.910
